# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
withAttack32 = pandas.read_csv("./with-attack-32.txt", sep=" ", header=None)
# withAttack16 = pandas.read_csv("./with-attack-16.txt", sep=" ", header=None)
withoutAttack32 = pandas.read_csv("./without-attack-32.txt", sep=" ", header=None)
# withoutAttack16 = pandas.read_csv("./without-attack-16.txt", sep=" ", header=None)
with26 = pandas.read_csv("./with-26.txt", sep=" ", header=None)
withhalf = pandas.read_csv("./with-5000.txt", sep=" ", header=None)
test = pandas.read_csv("./test.txt", sep=" ", header=None)
testAttack = pandas.read_csv("./test-attack.txt", sep=" ", header=None)
sameAttack32 = pandas.read_csv("./same-attack-32.txt", sep=" ", header=None)
# sameAttack16 = pandas.read_csv("./same-attack-16.txt", sep=" ", header=None)
plt.plot(withAttack32[1], label="attack 32")
# plt.plot(withAttack16[1], label="attack 16")
plt.plot(withoutAttack32[1], label="32")
# plt.plot(withoutAttack16[1], label="16")
plt.plot(sameAttack32[1], label="same 32")
# plt.plot(sameAttack16[1], label="same 16")
# plt.plot(test[1], label="test")
plt.plot(testAttack[1], label="testAttack")
plt.plot(withhalf[1], label="50% nodes dead 32")
plt.plot(with26[1], label="26")
plt.xlabel("Round")
plt.ylabel("Completeness")
plt.legend()

# %%
# withAttack32 = pandas.read_csv("./with-attack-32.txt", sep=" ", header=None)
withAttack16 = pandas.read_csv("./with-attack-16.txt", sep=" ", header=None)
withoutAttack32 = pandas.read_csv("./without-attack-32.txt", sep=" ", header=None)
withoutAttack16 = pandas.read_csv("./without-attack-16.txt", sep=" ", header=None)
with26 = pandas.read_csv("./with-26.txt", sep=" ", header=None)
withhalf = pandas.read_csv("./with-5000.txt", sep=" ", header=None)
test = pandas.read_csv("./test.txt", sep=" ", header=None)
testAttack = pandas.read_csv("./test-attack.txt", sep=" ", header=None)
sameAttack32 = pandas.read_csv("./same-attack-32.txt", sep=" ", header=None)
sameAttack16 = pandas.read_csv("./same-attack-16.txt", sep=" ", header=None)
plt.plot(withAttack32[1], label="attack 32")
plt.plot(withAttack16[1], label="attack 16")
plt.plot(withoutAttack32[1], label="32")
plt.plot(withoutAttack16[1], label="16")
plt.plot(sameAttack32[1], label="same 32")
plt.plot(sameAttack16[1], label="same 16")
# plt.plot(test[1], label="test")
# plt.plot(testAttack[1], label="testAttack")
plt.plot(withhalf[1], label="50% nodes dead 32")
plt.plot(with26[1], label="26")
plt.xlabel("Round")
plt.ylabel("Completeness")
plt.legend()
