# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
withAttack = pandas.read_csv("./with-attack.txt", sep=" ", header=None)
withoutAttack = pandas.read_csv("./without-attack.txt", sep=" ", header=None)

# %%
plt.plot(data[1])
